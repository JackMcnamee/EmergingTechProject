# %% [markdown]
# # Training the dataset model
# ***

# %%
# plotting
import matplotlib.pyplot as plt

# data frames
import pandas as pd

# neural networks
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# download data into a Pandas DataFrame
dataset = pd.read_csv("Dataset.csv")
dataset
# Out:
#       speed  power
# 0     0.000    0.0
# 1     0.125    0.0
# 2     0.150    0.0
# 3     0.225    0.0
# 4     0.275    0.0
# ..      ...    ...
# 495  24.775    0.0
# 496  24.850    0.0
# 497  24.875    0.0
# 498  24.950    0.0
# 499  25.000    0.0
#
# [500 rows x 2 columns]

# %%
# seperate power and speed values
dataset_power = dataset.copy()
dataset_speed = dataset_power.pop("speed")

# plot the dataset
plt.title('Wind Speed and Turbine Power Values')
plt.xlabel('Speed')
plt.ylabel('Power')
plt.plot(dataset_speed, dataset_power)

# %%
# regression model to predict power
dataset_model = tf.keras.Sequential([
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='relu'),
])

# configures dataset_model for training
dataset_model.compile('adam', loss='mean_squared_error')

# %%
batch_size = 500
epochs = 5000

# train dataset_model for 5000 epochs with
# a batch_size of 500 (number of samples per gradient update)
dataset_model.fit(dataset_speed, dataset_power, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 3214.5215
# Epoch 2/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 3165.2241
# Epoch 3/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 3114.6382
# Epoch 4/5000
# 1/1 [==============================] - 0s 996us/step - loss: 3062.0481
# Epoch 5/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 3008.0056
# Epoch 6/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 2952.3535
# Epoch 7/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 2894.8167
# Epoch 8/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 2835.3799
# Epoch 9/5000
# 1/1 [==============================] - 0s 1000us/step - loss: 2774.0474
# Epoch 10/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 2710.0879
# Epoch 11/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 2643.9209
# Epoch 12/5000
# ...

# %%
# predict power values from the entered speed values
dataset_model.predict([3.729,25.0,8.659])
# Out:
# array([[ 2.4468076],
#        [ 0.       ],
#        [11.010008 ]], dtype=float32)

# %% [markdown]
# From looking at the dataset, you can see that my model is fairly accurate as a speed of 25 is equal to 0 power. However, in the dataset, a speed of 3.729 is equal to 4.595 power, not 2.447, the value my model predicted.

# %%
# save model to use in web service
dataset_model.save("model.h5")

# %% [markdown]
# ### Explaining model
# ***

# %% [markdown]
# For building this model I used a Sequential model, as a Sequential model is appropriate for a plain stack of layers, where each layer has exactly one input tensor and one output tensor. To compile the model I used the adam optimizer and the
# mean squared error loss function. The adam optimizer is used to update network weights iteratively based in training data. The mean squared loss function is the sum of squared distances between the target variable and the predicted values. Finally, I trained the model with the dataset inputs, 5000 epochs and a bacth size of 500.

# %% [markdown]
# ### References
# ***

# %% [markdown]
# https://machinelearningmastery.com/how-to-make-classification-and-regression-predictions-for-deep-learning-models-in-keras/
#
# https://heartbeat.fritz.ai/5-regression-loss-functions-all-machine-learners-should-know-4fb140e9d4b0
#
# https://www.kdnuggets.com/2018/06/keras-4-step-workflow.html
#
# https://keras.io/examples/vision/mnist_convnet/
#
# https://github.com/ianmcloughlin/jupyter-teaching-notebooks/blob/master/keras-linear.ipynb
